# %% [markdown]
# ## 💼 **Visualizing Employment Data** 📈

# %% [markdown]
# Import standard libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt
import matplotlib.dates as mdates
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## **Q1: Convert datestamp column to a datetime object and set the datestamp columns as the index of your DataFrame**

# %% [markdown]
# Importing the Data:

# %%
df = pd.read_csv("C:\\Users\\gouri\\Downloads\\employment.csv")

# %%
df.head()
# Out:
#     datestamp  Agriculture  Business services  Construction  \
# 0  2000-01-01         10.3                5.7           9.7
# 1  2000-02-01         11.5                5.2          10.6
# 2  2000-03-01         10.4                5.4           8.7
# 3  2000-04-01          8.9                4.5           5.8
# 4  2000-05-01          5.1                4.7           5.0
#
#    Durable goods manufacturing  Education and Health  Finance  Government  \
# 0                          3.2                   2.3      2.7         2.1
# 1                          2.9                   2.2      2.8         2.0
# 2                          2.8                   2.5      2.6         1.5
# 3                          3.4                   2.1      2.3         1.3
# 4                          3.4                   2.7      2.2         1.9
#
#    Information  Leisure and hospitality  Manufacturing  Mining and Extraction  \
# ...

# %% [markdown]
# Converting the datestamp column into datetime objects

# %%
df["datestamp"] = pd.to_datetime(df["datestamp"], format="%Y-%m-%d")
df.head()
# Out:
#    datestamp  Agriculture  Business services  Construction  \
# 0 2000-01-01         10.3                5.7           9.7
# 1 2000-02-01         11.5                5.2          10.6
# 2 2000-03-01         10.4                5.4           8.7
# 3 2000-04-01          8.9                4.5           5.8
# 4 2000-05-01          5.1                4.7           5.0
#
#    Durable goods manufacturing  Education and Health  Finance  Government  \
# 0                          3.2                   2.3      2.7         2.1
# 1                          2.9                   2.2      2.8         2.0
# 2                          2.8                   2.5      2.6         1.5
# 3                          3.4                   2.1      2.3         1.3
# 4                          3.4                   2.7      2.2         1.9
#
#    Information  Leisure and hospitality  Manufacturing  Mining and Extraction  \
# 0          3.4                      7.5            3.6                    3.9
# ...

# %%
df = df.set_index('datestamp')

# %% [markdown]
# ## **Check that there are no missing values in each column:**

# %%
#There are no missing values in any column
df.isna().any()
# Out:
# Agriculture                       False
# Business services                 False
# Construction                      False
# Durable goods manufacturing       False
# Education and Health              False
# Finance                           False
# Government                        False
# Information                       False
# Leisure and hospitality           False
# Manufacturing                     False
# Mining and Extraction             False
# Nondurable goods manufacturing    False
# Other                             False
# Self-employed                     False
# Transportation and Utilities      False
# Wholesale and Retail Trade        False
# dtype: bool

# %% [markdown]
# ## **Q2: Generate a boxplot to find the distribution of unemployment rate for every industry**

# %%
bp = df.boxplot(fontsize=25, figsize = (30, 15))
pt.xticks(rotation = 30)
plt.title("Distribution of Unemployment Rate Across Industries", fontsize=40)
# Out:
# Text(0.5, 1.0, 'Distribution of Unemployment Rate Across Industries')

# %% [markdown]
# ## **Q3: Using line chart Visualize the unemployment rate of workers by industry**

# %%
df.plot(subplots=True, figsize=(10, 15))
plt.title("Unemployment Rate of Workers by Industry")
# Out:
# Text(0.5, 1.0, 'Unemployment Rate of Workers by Industry')

# %% [markdown]
# ## **Q4: Plot the monthly and yearly trends**

# %%
df_month = df.resample("M").mean()
df_year = df.resample("Y").mean()

# %%
#Monthly Trends
a = df_month.plot(fontsize = 20, figsize=(20, 15))
plt.title("Monthly Trends of Unemployment Across Industries", fontsize=30)
plt.xlabel("Date (in Years)", fontsize = 20)
# Out:
# Text(0.5, 0, 'Date (in Years)')

# %% [markdown]
# ## **Plotting the Yearly Trends:**

# %%
df_year.plot(fontsize = 20, figsize=(20, 10))
plt.title("Yearly Trends of Unemployment Across Industries", fontsize=30)
plt.xlabel("Date (in Years)", fontsize = 20)
# Out:
# Text(0.5, 0, 'Date (in Years)')

# %% [markdown]
# ## **Q5: Apply time series decomposition to your dataset to visualize the trend and seasonality**

# %%
from matplotlib import pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

clmn = ["Agriculture", "Business services", "Construction", "Durable goods manufacturing", "Education and Health", "Finance", "Government", "Information", "Leisure and hospitality", "Manufacturing", "Mining and Extraction", "Nondurable goods manufacturing", "Other", "Self-employed", "Transportation and Utilities", "Wholesale and Retail Trade"]
i = 0
for (columnName, columnData) in df[clmn].iteritems(): 
    fig = plt.figure()
    ad = fig.add_subplot(111)
    ad.set_title("Trend and Seasonality of " + df[clmn].columns[i] + " Industry", fontsize = 15)
    graph = seasonal_decompose(df[columnName], model='additive')
    graph.seasonal.plot()
    graph.trend.plot()
    plt.legend(loc="upper right")
    plt.xlabel("Date in Years", fontsize = 15)
    i += 1

# %% [markdown]
# ## **Q6: Visualize the seasonality of Agriculture, Health and Finance sector**

# %%
new = ["Agriculture", "Education and Health", "Finance"]
i = 0
for (columnName, columnData) in df[new].iteritems():
    fig = plt.figure()
    ad = fig.add_subplot(111)
    ad.set_title("Seasonality of " + df[new].columns[i] + " Industry", fontsize = 25)
    graph = seasonal_decompose(df[columnName], model='additive')
    graph.seasonal.plot()
    plt.legend(loc="upper right")
    plt.xlabel("Date in Years", fontsize = 15)
    i += 1

# %% [markdown]
# ## **Q7: Visualize the correlation between each time series in the dataset**

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(df.corr(), annot = True, linewidths=0)
# Out:
# <AxesSubplot:>
